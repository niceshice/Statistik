# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ger_childrens_book_authors = pd.read_csv(r"D:/cravi/Documents/Uni/DH/Statistik/Data/KinderautorenD20Jhdt.tsv", sep="\t")
ger_childrens_book_authors["Lebensspanne"] = ger_childrens_book_authors["Todesjahr"] - ger_childrens_book_authors["Geburtsjahr"]
ger_childrens_book_authors.head(3)
# Out:
#           Nachname   Vorname  Geburtsjahr  Todesjahr  Lebensspanne
# 0          Abraham     Peter         1936       2015            79
# 1          Aichner  Fridolin         1912       1987            75
# 2  Alexander-Burgh  Eberhard         1929       2004            75

# %% [markdown]
# #### Barplot Lebensspanne
# ..der Autoren aus dem eigenen Datensatz

# %%
ger_childrens_book_authors.sort_values(by = "Lebensspanne").plot.bar(figsize=(20,5), x = "Nachname", y = "Lebensspanne", color ="blue", title = "Lebensspannen der Autoren")

# %% [markdown]
# ##### Dazugehöriges Histogramm

# %%
ger_childrens_book_authors["Lebensspanne"].plot.hist(x = "Lebensspanne in Jahre", bins = 25, title = "Verteilung der Lebensspannen")

# %%
sns.distplot(ger_childrens_book_authors['Lebensspanne'], bins=25, kde=True)
# Out:
# d:\languages\python\python3.6.3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Die Lebensspannen sind annähernd Normalverteilt, die Daten sind kontinuerlich.

# %%
ayl_speaker_data = pd.read_csv(r"D:/cravi/Documents/Uni/DH/Statistik/Data/AYLSpeakerData.csv", sep=";")
ayl_speaker_data.head(3)
# Out:
#    ID           label gender  per_ms_sps         role importance
# 0   0         orlando   male         120  protagonist    primary
# 1   1          oliver   male          40   antagonist    primary
# 2   2  second brother   male           2        other      minor

# %% [markdown]
# #### Barplot der per_ms_sps

# %%
ayl_speaker_data.sort_values(by = "per_ms_sps", ascending = False).plot.bar(figsize=(20,5), x = "label", y = "per_ms_sps", color = "blue", title = "Redebeiträge pro Charakter")
plt.xlabel("Character Label")
plt.ylabel("Occurence of Speech")
# Out:
# Text(0,0.5,'Occurence of Speech')

# %%
ayl_speaker_data["per_ms_sps"].plot.box()

# %% [markdown]
# Der Barplot folgt der Zipf-Verteilung. Die gezählten Ereignisse sind nicht unabhängig voneinander, deswegen liegt keine Poisson-Verteilung vor.
